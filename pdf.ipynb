# %% [markdown]
# <a href="https://colab.research.google.com/github/saraalim2001/NER/blob/master/pdf.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Extract text from pdf

# %%
# !pip install PyPDF2
# Out:
# ...
#      |████████████████████████████████| 81kB 2.6MB/s
# ...
#   Created wheel for PyPDF2: filename=PyPDF2-1.26.0-cp37-none-any.whl size=61085 sha256=84738ed90b9f1aecebd9bd559f435b17d39a6cc56849d658df73baa2dbe72cc0
#   Stored in directory: /root/.cache/pip/wheels/53/84/19/35bc977c8bf5f0c23a8a011aa958acd4da4bbd7a229315c1b7
# Successfully built PyPDF2
# ...

# %%
import PyPDF2 as pdf

# %%
file = open('/content/drive/MyDrive/Dataset/pdf/Tasks.pdf', 'rb')
file
# Out:
# <_io.BufferedReader name='/content/drive/MyDrive/Dataset/pdf/Tasks.pdf'>

# %%
pdf_reader = pdf.PdfFileReader(file)
pdf_reader

# %%
help(pdf_reader)
# Out:
# Help on PdfFileReader in module PyPDF2.pdf object:
#
# class PdfFileReader(builtins.object)
#  |  PdfFileReader(stream, strict=True, warndest=None, overwriteWarnings=True)
#  |
#  |  Initializes a PdfFileReader object.  This operation can take some time, as
#  |  the PDF stream's cross-reference tables are read into memory.
#  |
#  |  :param stream: A File object or an object that supports the standard read
#  |      and seek methods similar to a File object. Could also be a
#  |      string representing a path to a PDF file.
#  |  :param bool strict: Determines whether user should be warned of all
#  |      problems and also causes some correctable problems to be fatal.
#  |      Defaults to ``True``.
#  |  :param warndest: Destination for logging warnings (defaults to
#  |      ``sys.stderr``).
#  |  :param bool overwriteWarnings: Determines whether to override Python's
#  |      ``warnings.py`` module with a custom implementation (defaults to
#  |      ``True``).
#  |
# ...

# %%
pdf_reader.getNumPages()
# Out:
# 14

# %%
page1 = pdf_reader.getPage(0)

# %%
text=page1.extractText()[:1050]

# %%
text
# Out:
# 'SAMPLE TASKS \nFollowing are some sample tasks that will allow us to evaluate your talent.  \nIf you have done the previous tasks (older version) and submitted them then it is not \nnecessary for you to complete some from here. However it is always better to be \nproactive and you are free to do some more of these tasks. \nNOTE \nYou can do a maximum of 2 tasks, if nothing is mentioned explicitly. If otherwise \nmentioned please follow the guidelines. Tasks have no specific time limit and evaluations \nare done while we hire interns monthly or weekly (depending on roles). The format for \nsubmitting the tasks is in Documents/Spreadsheets/Videos/Graphic/Code or any other \nway you would like to present your task (again unless otherwise mentioned). You can \nupload your files onto a cloud drive and submit the link for the same if they are larger \nthan 5mb or unconventional formats. For smaller conventional files an attachment option \nwill be provided within the given form. Please su
# ...

# %% [markdown]
# #Sentence Boundary Detection

# %%
import nltk
from nltk.tokenize import sent_tokenize
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
sentences=sent_tokenize(text)

# %%
sentences
# Out:
# ['SAMPLE TASKS \nFollowing are some sample tasks that will allow us to evaluate your talent.',
#  'If you have done the previous tasks (older version) and submitted them then it is not \nnecessary for you to complete some from here.',
#  'However it is always better to be \nproactive and you are free to do some more of these tasks.',
#  'NOTE \nYou can do a maximum of 2 tasks, if nothing is mentioned explicitly.',
#  'If otherwise \nmentioned please follow the guidelines.',
#  'Tasks have no specific time limit and evaluations \nare done while we hire interns monthly or weekly (depending on roles).',
#  'The format for \nsubmitting the tasks is in Documents/Spreadsheets/Videos/Graphic/Code or any other \nway you would like to present your task (again unless otherwise mentioned).',
#  'You can \nupload your files onto a cloud drive and submit the link for the same if they are larger \nthan 5mb or unconventional formats.',
# ...

# %% [markdown]
# #NER

# %%
import spacy
from spacy import displacy
from collections import Counter
import en_core_web_sm
nlp = en_core_web_sm.load()

# %%
doc=nlp(text)
len(doc.ents)
# Out:
# 4

# %%
pprint([(X.text, X.label_) for X in doc.ents])
# Out:
# Pretty printing has been turned OFF

# %%
labels = [x.label_ for x in doc.ents]
Counter(labels)
# Out:
# Counter({'DATE': 2, 'CARDINAL': 1, 'ORG': 1})

# %%
pprint([(X, X.ent_iob_, X.ent_type_) for X in doc])
# Out:
# Pretty printing has been turned ON

# %%
items = [x.text for x in doc.ents]
Counter(items).most_common(3)
# Out:
# [('2', 1), ('monthly', 1), ('weekly', 1)]

# %%
displacy.render(nlp(str(sentences)), jupyter=True, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">[
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     'SAMPLE TASKS \nFollowing
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">WORK_OF_ART</span>
# </mark>
#  are some sample tasks that will allow us to evaluate your talent.', 'If you have done the previous tasks (older version) and submitted them then it is not \nnecessary for you to complete some from here.', 'However it is always better to be \nproactive and you are free to do some more of these tasks.', 'NOTE \nYou can do a maximum of
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2
# ...

# %%
displacy.render(nlp(str(sentences)), style='dep', jupyter = True, options = {'distance': 90})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="05846d816129458787f179a012f6e7e5-0" class="displacy" width="15890" height="857.0" direction="ltr" style="max-width: none; height: 857.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="767.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">[</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PUNCT</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="767.0">
#     <tspan class="displacy-word" fill="currentColor" x="140">'</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="140">PUNCT</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="767.0">
# ...

# %%
[(x.orth_,x.pos_, x.lemma_) for x in [y 
                                      for y
                                      in nlp(str(sentences)) 
                                      if not y.is_stop and y.pos_ != 'PUNCT']]
# Out:
# [('SAMPLE', 'NOUN', 'sample'),
#  ('TASKS', 'NOUN', 'task'),
#  ('\\nFollowing', 'NOUN', '\\nfollowing'),
#  ('sample', 'NOUN', 'sample'),
#  ('tasks', 'NOUN', 'task'),
#  ('allow', 'VERB', 'allow'),
#  ('evaluate', 'VERB', 'evaluate'),
#  ('talent', 'NOUN', 'talent'),
#  ('previous', 'ADJ', 'previous'),
#  ('tasks', 'NOUN', 'task'),
#  ('older', 'ADJ', 'old'),
#  ('version', 'NOUN', 'version'),
#  ('submitted', 'VERB', 'submit'),
#  ('\\nnecessary', 'ADJ', '\\nnecessary'),
#  ('complete', 'VERB', 'complete'),
#  ('better', 'ADJ', 'well'),
#  ('\\nproactive', 'NUM', '\\nproactive'),
#  ('free', 'ADJ', 'free'),
#  ('tasks', 'NOUN', 'task'),
#  ('NOTE', 'NOUN', 'note'),
#  ('\\nYou', 'NOUN', '\\nYou'),
#  ('maximum', 'NOUN', 'maximum'),
#  ('2', 'NUM', '2'),
#  ('tasks', 'NOUN', 'task'),
#  ('mentioned', 'VERB', 'mention'),
#  ('explicitly', 'ADV', 'explicitly'),
#  ('\\nmentioned', 'NUM', '\\nmentioned'),
#  ('follow', 'VERB', 'follow'),
#  ('guidelines', 'NOUN', 'guideline'),
# ...

# %%
dict([(str(x), x.label_) for x in nlp(str(sentences)).ents])
# Out:
# {"'SAMPLE TASKS \\nFollowing": 'WORK_OF_ART',
#  '2': 'CARDINAL',
#  '5mb': 'QUANTITY',
#  'Documents/Spreadsheets/Videos/Graphic/Code': 'ORG',
#  'You can \\nupload': 'WORK_OF_ART',
#  '\\nmentioned': 'GPE',
#  '\\nthan': 'GPE',
#  'monthly': 'DATE',
#  'weekly': 'DATE'}

# %%
displacy.render(doc, jupyter=True, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">SAMPLE TASKS </br>Following are some sample tasks that will allow us to evaluate your talent.  </br>If you have done the previous tasks (older version) and submitted them then it is not </br>necessary for you to complete some from here. However it is always better to be </br>proactive and you are free to do some more of these tasks. </br>NOTE </br>You can do a maximum of
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  tasks, if nothing is mentioned explicitly. If otherwise </br>mentioned please follow the guidelines. Tasks have no specific time limit and evaluations </br>are done while we hire interns
# ...
